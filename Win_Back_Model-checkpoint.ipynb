# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_new = pd.read_csv(r'Watcho_DA_Subs_new_Mar12', sep='\t', encoding='utf-8', index_col=0)

# %%
df_new.head()
# Out:
#         smsid             RevenueRenewal  Days_since_last_renewal  \
# 0  31662470.0                    Service                    414.0
# 1  31705998.0           Digital-Campaign                    320.0
# 2  31758936.0           Digital-Campaign                    134.0
# 3  31788375.0           Digital-Campaign                    176.0
# 4  31811554.0  RMT-Free Sampling on PGAR                      NaN
#
#    customercategory  AON          Current_Debit_mode  current_packageid  \
# 0                 1  560                          PG              35919
# 1                 3  903  Cancelled- PG auto renewal             160988
# 2                 2  657                      Wallet             161056
# 3                 3  659  Cancelled- PG auto renewal             160988
# 4                 1  262                          PG             117280
#
#   Smart_Plus_Customer  no_of_renewals Status_on_30Nov  ...  \
# 0              Others             1.0        Deactive  ...
# 1              Others             8.0        Deactive  ...
# 2              Others             9.0        Deactive  ...
# 3              Others             7.0        Deactive  ...
# 4              Others             NaN        Deactive  ...
#
#    notification_sent_sms_FEB_25  notification_clicked_DEC_24  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           3.0                          NaN
# 4                           3.0                          NaN
#
#   notification_clicked_JAN_25 notification_clicked_FEB_25  \
# 0                         NaN                         NaN
# 1                         NaN                         NaN
# 2                         NaN                         NaN
# 3                         NaN                         NaN
# 4                         NaN                         NaN
#
#    notification_sent_watsapp_DEC_24  notification_sent_watsapp_JAN_25  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               5.0                               5.0
# 4                               1.0                               2.0
#
#    notification_sent_watsapp_FEB_25  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                              12.0
# 4                               1.0
#
#    no_of_times_viewed_clicked_content_in_last_3_months_HotStar  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    no_of_times_viewed_clicked_content_in_last_3_months_Zee5  is_first_time_da
# 0                                                NaN                        0
# 1                                                NaN                        0
# 2                                                NaN                        0
# 3                                                NaN                        0
# 4                                                NaN                        1
#
# [5 rows x 46 columns]

# %%
df_new.describe()
# Out:
#               smsid  Days_since_last_renewal  customercategory           AON  \
# count  1.089845e+06            537084.000000      1.089845e+06  1.089845e+06
# mean   6.204668e+07               231.836011      1.867905e+00  3.360979e+02
# std    7.526568e+06                97.985801      8.786753e-01  1.590566e+02
# min    3.166247e+07                95.000000      1.000000e+00  9.500000e+01
# 25%    5.675490e+07               143.000000      1.000000e+00  2.050000e+02
# 50%    6.507187e+07               213.000000      2.000000e+00  3.250000e+02
# 75%    6.780830e+07               311.000000      3.000000e+00  4.200000e+02
# max    7.109688e+07               429.000000      9.000000e+00  9.080000e+02
#
#        current_packageid  no_of_renewals  last_price_point     DTH_Status  \
# count       1.089845e+06    537084.00000     537084.000000  455129.000000
# mean        1.319509e+05         3.01508        272.263788       1.523309
# std         3.347995e+04         2.74189        370.243300       0.501989
# min         3.591900e+04         1.00000       -358.000000       1.000000
# 25%         1.172750e+05         1.00000         72.600000       1.000000
# 50%         1.172780e+05         2.00000        179.000000       2.000000
# 75%         1.609880e+05         4.00000        321.300000       2.000000
# max         1.901970e+05        52.00000      36574.020000       3.000000
#
#        Is_hotstar_subscriber  Is_sonyliv_subscriber  ...  \
# count               675354.0               528145.0  ...
# mean                     1.0                    1.0  ...
# std                      0.0                    0.0  ...
# min                      1.0                    1.0  ...
# 25%                      1.0                    1.0  ...
# 50%                      1.0                    1.0  ...
# 75%                      1.0                    1.0  ...
# max                      1.0                    1.0  ...
#
#        notification_sent_sms_FEB_25  notification_clicked_DEC_24  \
# count                 172594.000000                   796.000000
# mean                       3.623475                     1.159548
# std                        2.825167                     0.435439
# min                        1.000000                     1.000000
# 25%                        1.000000                     1.000000
# 50%                        3.000000                     1.000000
# 75%                        5.000000                     1.000000
# max                       20.000000                     4.000000
#
#        notification_clicked_JAN_25  notification_clicked_FEB_25  \
# count                 29661.000000                 26553.000000
# mean                      9.017902                     6.110345
# std                      12.219808                     7.754385
# min                       1.000000                     1.000000
# 25%                       1.000000                     1.000000
# 50%                       3.000000                     3.000000
# 75%                      11.000000                     7.000000
# max                     111.000000                   130.000000
#
#        notification_sent_watsapp_DEC_24  notification_sent_watsapp_JAN_25  \
# count                     136307.000000                     184817.000000
# mean                           2.189095                          3.021232
# std                            1.175947                          1.737762
# min                            1.000000                          1.000000
# 25%                            1.000000                          2.000000
# 50%                            2.000000                          3.000000
# 75%                            3.000000                          4.000000
# max                           24.000000                         32.000000
#
#        notification_sent_watsapp_FEB_25  \
# count                     148326.000000
# mean                           3.039083
# std                            1.944468
# min                            1.000000
# 25%                            2.000000
# 50%                            3.000000
# 75%                            4.000000
# max                           33.000000
#
#        no_of_times_viewed_clicked_content_in_last_3_months_HotStar  \
# count                                       12823.000000
# mean                                            2.524292
# std                                             3.792938
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             3.000000
# max                                            92.000000
#
#        no_of_times_viewed_clicked_content_in_last_3_months_Zee5  \
# count                                       11339.000000
# mean                                            2.535673
# std                                             4.777538
# min                                             1.000000
# 25%                                             1.000000
# 50%                                             1.000000
# 75%                                             3.000000
# max                                           270.000000
#
#        is_first_time_da
# count      1.089845e+06
# mean       5.071923e-01
# std        4.999485e-01
# min        0.000000e+00
# 25%        0.000000e+00
# 50%        1.000000e+00
# 75%        1.000000e+00
# max        1.000000e+00
#
# [8 rows x 39 columns]

# %% [raw]
# # Won't work as there are numeric categories or the columns are flags as 1 or 0
# # Identify numeric and categorical columns
# numeric_columns = df_new.select_dtypes(include=['number']).columns.tolist()
# categorical_columns = df_new.select_dtypes(include=['object']).columns.tolist()

# %%
df_new['RevenueRenewal'].value_counts()
# Out:
# RevenueRenewal
# OB                           278018
# Service                      210990
# Hybrid_Upgrade               182777
# Trade                        116320
# Digital-Campaign             110122
# Digital-Coupon                69968
# Sampling                      35582
# B2B-non Sampling              33592
# Hybrid_Acq                    17063
# RMT-Hybrid                    15505
# RMT-Free Sampling on PGAR     14683
# RMT- Discounted price          4996
# Hybrid_acq                      185
# OB-Hybrid                         9
# sampling                          1
# Digital-Cashback                  1
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df_new['RevenueRenewal'])
plt.title(f'Distribution of RevenueRenewal')
plt.xticks(rotation=45)
plt.show()

# %%
df_new['Status_on_30Nov'].value_counts()
# Out:
# Status_on_30Nov
# Deactive    1089845
# Name: count, dtype: int64

# %%
categorical_columns = [
# Out:
# ['RevenueRenewal',
#  'Current_Debit_mode',
#  'Smart_Plus_Customer',
#  'Status_on_30Nov',
#  'activationdate',
#  'Last_Renewal_date',
#  'Status_As_on_28Feb']

# %%
numeric_columns
# Out:
# ['smsid',
#  'Days_since_last_renewal',
#  'customercategory',
#  'AON',
#  'current_packageid',
#  'no_of_renewals',
#  'last_price_point',
#  'DTH_Status',
#  'Is_hotstar_subscriber',
#  'Is_sonyliv_subscriber',
#  'Is_zee5_subscriber',
#  'Is_livetv_subscriber',
#  'Is_hungama_subscriber',
#  'Is_fancode_subscriber',
#  'Is_chaupal_subscriber',
#  'ActiveDays_Dec24',
#  'ActiveDays_Jan25',
#  'ActiveDays_Feb25',
#  'Revenue_Dec24',
#  'Revenue_Jan25',
#  'Revenue_Feb25',
#  'no_of_times_viewed_watcho_content_in_last_3_months',
#  'no_of_times_viewed_watcho_content_in_last_3_months_HotStar',
#  'no_of_times_viewed_watcho_content_in_last_3_months_Zee5',
#  'notification_sent_DEC_24',
#  'notification_sent_JAN_25',
#  'notification_sent_FEB_25',
#  'notification_sent_sms_DEC_24',
#  'notification_sent_sms_JAN_25',
#  'notification_sent_sms_FEB_25',
#  'notification_clicked_DEC_24',
#  'notification_clicked_JAN_25',
#  'notification_clicked_FEB_25',
#  'notification_sent_watsapp_DEC_24',
#  'notification_sent_watsapp_JAN_25',
#  'notification_sent_watsapp_FEB_25',
#  'no_of_times_viewed_clicked_content_in_last_3_months_HotStar',
#  'no_of_times_viewed_clicked_content_in_last_3_months_Zee5',
#  'is_first_time_da']

# %%
df_new['customercategory'].value_counts()
# Out:
# customercategory
# 1    457677
# 2    331215
# 3    298782
# 9      2118
# 4        53
# Name: count, dtype: int64

# %%
# Create data profile for numeric columns
for col in numeric_columns:
    print(f"Data Profile for Numeric Column: {col}")
    print(df_new[col].describe())
    plt.figure(figsize=(10, 5))
    sns.histplot(df_new[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()
# Out:
# Data Profile for Numeric Column: smsid
# count    1.089845e+06
# mean     6.204668e+07
# std      7.526568e+06
# min      3.166247e+07
# 25%      5.675490e+07
# 50%      6.507187e+07
# 75%      6.780830e+07
# max      7.109688e+07
# Name: smsid, dtype: float64
# Data Profile for Numeric Column: Days_since_last_renewal
# count    537084.000000
# mean        231.836011
# std          97.985801
# min          95.000000
# 25%         143.000000
# 50%         213.000000
# 75%         311.000000
# max         429.000000
# Name: Days_since_last_renewal, dtype: float64
# Data Profile for Numeric Column: customercategory
# count    1.089845e+06
# mean     1.867905e+00
# std      8.786753e-01
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      2.000000e+00
# 75%      3.000000e+00
# max      9.000000e+00
# Name: customercategory, dtype: float64
# Data Profile for Numeric Column: AON
# count    1.089845e+06
# mean     3.360979e+02
# std      1.590566e+02
# min      9.500000e+01
# 25%      2.050000e+02
# 50%      3.250000e+02
# 75%      4.200000e+02
# max      9.080000e+02
# Name: AON, dtype: float64
# Data Profile for Numeric Column: current_packageid
# count    1.089845e+06
# mean     1.319509e+05
# std      3.347995e+04
# min      3.591900e+04
# 25%      1.172750e+05
# 50%      1.172780e+05
# 75%      1.609880e+05
# max      1.901970e+05
# Name: current_packageid, dtype: float64
# Data Profile for Numeric Column: no_of_renewals
# count    537084.00000
# mean          3.01508
# std           2.74189
# min           1.00000
# 25%           1.00000
# 50%           2.00000
# 75%           4.00000
# max          52.00000
# Name: no_of_renewals, dtype: float64
# Data Profile for Numeric Column: last_price_point
# count    537084.000000
# mean        272.263788
# std         370.243300
# min        -358.000000
# 25%          72.600000
# 50%         179.000000
# 75%         321.300000
# max       36574.020000
# Name: last_price_point, dtype: float64
# Data Profile for Numeric Column: DTH_Status
# count    455129.000000
# mean          1.523309
# std           0.501989
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           2.000000
# max           3.000000
# Name: DTH_Status, dtype: float64
# Data Profile for Numeric Column: Is_hotstar_subscriber
# count    675354.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0
# Name: Is_hotstar_subscriber, dtype: float64
# Data Profile for Numeric Column: Is_sonyliv_subscriber
# count    528145.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0
# Name: Is_sonyliv_subscriber, dtype: float64
# Data Profile for Numeric Column: Is_zee5_subscriber
# count    947287.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0
# Name: Is_zee5_subscriber, dtype: float64
# Data Profile for Numeric Column: Is_livetv_subscriber
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: Is_livetv_subscriber, dtype: float64
# Data Profile for Numeric Column: Is_hungama_subscriber
# count    1077610.0
# mean           1.0
# std            0.0
# min            1.0
# 25%            1.0
# 50%            1.0
# 75%            1.0
# max            1.0
# Name: Is_hungama_subscriber, dtype: float64
# Data Profile for Numeric Column: Is_fancode_subscriber
# count    1087132.0
# mean           1.0
# std            0.0
# min            1.0
# 25%            1.0
# 50%            1.0
# 75%            1.0
# max            1.0
# Name: Is_fancode_subscriber, dtype: float64
# Data Profile for Numeric Column: Is_chaupal_subscriber
# count    765930.0
# mean          1.0
# std           0.0
# min           1.0
# 25%           1.0
# 50%           1.0
# 75%           1.0
# max           1.0
# Name: Is_chaupal_subscriber, dtype: float64
# Data Profile for Numeric Column: ActiveDays_Dec24
# count    1.089845e+06
# mean     8.464818e-01
# std      4.218300e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      3.100000e+01
# Name: ActiveDays_Dec24, dtype: float64
# Data Profile for Numeric Column: ActiveDays_Jan25
# count    1.089801e+06
# mean     1.219900e+00
# std      5.354909e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      3.100000e+01
# Name: ActiveDays_Jan25, dtype: float64
# Data Profile for Numeric Column: ActiveDays_Feb25
# count    1.089802e+06
# mean     1.203181e+00
# std      5.138635e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.800000e+01
# Name: ActiveDays_Feb25, dtype: float64
# Data Profile for Numeric Column: Revenue_Dec24
# count    62487.000000
# mean        47.802951
# std         54.118396
# min       -293.000000
# 25%          2.000000
# 50%         36.000000
# 75%         76.000000
# max       1148.000000
# Name: Revenue_Dec24, dtype: float64
# Data Profile for Numeric Column: Revenue_Jan25
# count    59454.000000
# mean        64.232869
# std         57.783079
# min       -269.000000
# 25%         20.000000
# 50%         54.000000
# 75%         91.000000
# max        539.000000
# Name: Revenue_Jan25, dtype: float64
# Data Profile for Numeric Column: Revenue_Feb25
# count    53885.000000
# mean        62.959822
# std         54.239126
# min       -243.000000
# 25%         23.000000
# 50%         56.000000
# 75%         90.000000
# max        496.000000
# Name: Revenue_Feb25, dtype: float64
# Data Profile for Numeric Column: no_of_times_viewed_watcho_content_in_last_3_months
# count    17475.000000
# mean        22.656881
# std         83.654179
# min          1.000000
# 25%          1.000000
# 50%          4.000000
# 75%         14.000000
# max       2989.000000
# Name: no_of_times_viewed_watcho_content_in_last_3_months, dtype: float64
# Data Profile for Numeric Column: no_of_times_viewed_watcho_content_in_last_3_months_HotStar
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: no_of_times_viewed_watcho_content_in_last_3_months_HotStar, dtype: float64
# Data Profile for Numeric Column: no_of_times_viewed_watcho_content_in_last_3_months_Zee5
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: no_of_times_viewed_watcho_content_in_last_3_months_Zee5, dtype: float64
# Data Profile for Numeric Column: notification_sent_DEC_24
# count    306114.000000
# mean         34.164357
# std          58.093525
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%          16.000000
# max         290.000000
# Name: notification_sent_DEC_24, dtype: float64
# Data Profile for Numeric Column: notification_sent_JAN_25
# count    283756.000000
# mean         55.167588
# std          89.567908
# min           1.000000
# 25%           3.000000
# 50%           6.000000
# 75%          70.000000
# max         420.000000
# Name: notification_sent_JAN_25, dtype: float64
# Data Profile for Numeric Column: notification_sent_FEB_25
# count    248921.000000
# mean         57.781248
# std          88.790124
# min           1.000000
# 25%           3.000000
# 50%           6.000000
# 75%         113.000000
# max         393.000000
# Name: notification_sent_FEB_25, dtype: float64
# Data Profile for Numeric Column: notification_sent_sms_DEC_24
# count    242168.000000
# mean          2.212972
# std           1.698272
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max          17.000000
# Name: notification_sent_sms_DEC_24, dtype: float64
# Data Profile for Numeric Column: notification_sent_sms_JAN_25
# count    236308.000000
# mean          3.352908
# std           2.556490
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%           4.000000
# max          23.000000
# Name: notification_sent_sms_JAN_25, dtype: float64
# Data Profile for Numeric Column: notification_sent_sms_FEB_25
# count    172594.000000
# mean          3.623475
# std           2.825167
# min           1.000000
# 25%           1.000000
# 50%           3.000000
# 75%           5.000000
# max          20.000000
# Name: notification_sent_sms_FEB_25, dtype: float64
# Data Profile for Numeric Column: notification_clicked_DEC_24
# count    796.000000
# mean       1.159548
# std        0.435439
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        4.000000
# Name: notification_clicked_DEC_24, dtype: float64
# Data Profile for Numeric Column: notification_clicked_JAN_25
# count    29661.000000
# mean         9.017902
# std         12.219808
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%         11.000000
# max        111.000000
# Name: notification_clicked_JAN_25, dtype: float64
# Data Profile for Numeric Column: notification_clicked_FEB_25
# count    26553.000000
# mean         6.110345
# std          7.754385
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          7.000000
# max        130.000000
# Name: notification_clicked_FEB_25, dtype: float64
# Data Profile for Numeric Column: notification_sent_watsapp_DEC_24
# count    136307.000000
# mean          2.189095
# std           1.175947
# min           1.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max          24.000000
# Name: notification_sent_watsapp_DEC_24, dtype: float64
# Data Profile for Numeric Column: notification_sent_watsapp_JAN_25
# count    184817.000000
# mean          3.021232
# std           1.737762
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max          32.000000
# Name: notification_sent_watsapp_JAN_25, dtype: float64
# Data Profile for Numeric Column: notification_sent_watsapp_FEB_25
# count    148326.000000
# mean          3.039083
# std           1.944468
# min           1.000000
# 25%           2.000000
# 50%           3.000000
# 75%           4.000000
# max          33.000000
# Name: notification_sent_watsapp_FEB_25, dtype: float64
# Data Profile for Numeric Column: no_of_times_viewed_clicked_content_in_last_3_months_HotStar
# count    12823.000000
# mean         2.524292
# std          3.792938
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          3.000000
# max         92.000000
# Name: no_of_times_viewed_clicked_content_in_last_3_months_HotStar, dtype: float64
# Data Profile for Numeric Column: no_of_times_viewed_clicked_content_in_last_3_months_Zee5
# count    11339.000000
# mean         2.535673
# std          4.777538
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          3.000000
# max        270.000000
# Name: no_of_times_viewed_clicked_content_in_last_3_months_Zee5, dtype: float64
# Data Profile for Numeric Column: is_first_time_da
# count    1.089845e+06
# mean     5.071923e-01
# std      4.999485e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+00
# 75%      1.000000e+00
# max      1.000000e+00
# Name: is_first_time_da, dtype: float64
